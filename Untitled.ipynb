# %%
import matplotlib.pyplot as plt

# %%
import pickle

# %%
for i in range(0, 5):
    data = pickle.load(open('predator/commnet_trial_%s.pkl' % i, 'rb'))
    plt.plot(data['rewards'])

# %%
data = pickle.load(open('combat/commnet_trial_0.pkl', 'rb'))
plt.plot(data['rewards'])
